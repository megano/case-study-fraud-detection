# %%
import json
import datetime
import numpy as np
import pandas as pd
# from pandas_summary import DataFrameSummary

# %%
with open('data.json') as data_file:
  data = json.load(data_file)

df = pd.DataFrame.from_dict(data)

'''
[10:08]
df['fraud'] = df.acct_type.map(lambda x: 1 if ((x == 'fraudster') | (x == 'fraudster_att') | (x == 'fraudster_event')) else 0)
'''
# Out:
# "\n[10:08]\ndf['fraud'] = df.acct_type.map(lambda x: 1 if ((x == 'fraudster') | (x == 'fraudster_att') | (x == 'fraudster_event')) else 0)\n"

# %%
# dfs = DataFrameSummary(df)

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event          1266062400         3852         5      US
# 1          premium          1296720000         3499         0      US
# 2          premium          1296172800         2601         8      US
# 3          premium          1388966400        12347         6      IE
# 4          premium          1297900800         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df.describe()
# Out:
#        approx_payout_date   body_length      channels  delivery_method  \
# count        1.433700e+04  14337.000000  14337.000000     14321.000000
# mean         1.350933e+09   3672.521936      6.176676         0.439564
# std          2.401300e+07   5758.113003      3.860333         0.591487
# min          1.171256e+09      0.000000      0.000000         0.000000
# 25%          1.334221e+09    750.000000      5.000000         0.000000
# 50%          1.355805e+09   1990.000000      6.000000         0.000000
# 75%          1.370646e+09   4280.000000      8.000000         1.000000
# max          1.523488e+09  65535.000000     13.000000         3.000000
#
#        event_created     event_end  event_published   event_start  \
# count   1.433700e+04  1.433700e+04     1.423800e+04  1.433700e+04
# mean    1.345825e+09  1.350501e+09     1.340854e+09  1.350205e+09
# std     2.404107e+07  2.401299e+07     8.750386e+07  2.398787e+07
# ...

# %%
# convert time values to time type
df['approx_payout_date'] = df['approx_payout_date'].map(lambda x: datetime.datetime.fromtimestamp(x))

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event 2010-02-13 04:00:00         3852         5      US
# 1          premium 2011-02-03 00:00:00         3499         0      US
# 2          premium 2011-01-27 16:00:00         2601         8      US
# 3          premium 2014-01-05 16:00:00        12347         6      IE
# 4          premium 2011-02-16 16:00:00         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14337 entries, 0 to 14336
# Data columns (total 44 columns):
# acct_type             14337 non-null object
# approx_payout_date    14337 non-null datetime64[ns]
# body_length           14337 non-null int64
# channels              14337 non-null int64
# country               14256 non-null object
# currency              14337 non-null object
# delivery_method       14321 non-null float64
# description           14337 non-null object
# email_domain          14337 non-null object
# event_created         14337 non-null int64
# event_end             14337 non-null int64
# event_published       14238 non-null float64
# event_start           14337 non-null int64
# fb_published          14337 non-null int64
# gts                   14337 non-null float64
# has_analytics         14337 non-null int64
# has_header            8928 non-null float64
# has_logo              14337 non-null int64
# listed                14337 non-null object
# ...

# %%
''' 
Notes: 
gts
user type is a number: ex 14337.000000. 
listed: y or n 
payee_name 
payout_type: CHECK, ACH, etc, previous_payouts, 
sale_duration2
user_created: ex 1259613950
'''
# Out:
# ' \nNotes: \ngts\nuser type is a number: ex 14337.000000. \nlisted: y or n \npayee_name \npayout_type: CHECK, ACH, etc, previous_payouts, \nsale_duration2\nuser_created: ex 1259613950\n'

# %%
df.user_created.head()
# Out:
# 0    1259613950
# 1    1280942776
# 2    1272559388
# 3    1283870102
# 4    1288984065
# Name: user_created, dtype: int64

# %%
df.acct_type.nunique()
# Out:
# 12

# %%
df.acct_type.unique()
# Out:
# array([u'fraudster_event', u'premium', u'spammer_warn', u'fraudster',
#        u'spammer_limited', u'spammer_noinvite', u'locked', u'tos_lock',
#        u'tos_warn', u'fraudster_att', u'spammer_web', u'spammer'], dtype=object)

# %%
([u'fraudster_event', u'premium', u'spammer_warn', u'fraudster',
       u'spammer_limited', u'spammer_noinvite', u'locked', u'tos_lock',
       u'tos_warn', u'fraudster_att', u'spammer_web', u'spammer'])
# Out:
# [u'fraudster_event',
#  u'premium',
#  u'spammer_warn',
#  u'fraudster',
#  u'spammer_limited',
#  u'spammer_noinvite',
#  u'locked',
#  u'tos_lock',
#  u'tos_warn',
#  u'fraudster_att',
#  u'spammer_web',
#  u'spammer']

# %%
# Add a 'Fraud' column. If event type is 'fraudster_event' in acct_type field: True, else False.
df['fraud'] = (df['acct_type'] == 'fraudster_event')

# %%
df.head()
# Out:
#          acct_type  approx_payout_date  body_length  channels country  \
# 0  fraudster_event 2010-02-13 04:00:00         3852         5      US
# 1          premium 2011-02-03 00:00:00         3499         0      US
# 2          premium 2011-01-27 16:00:00         2601         8      US
# 3          premium 2014-01-05 16:00:00        12347         6      IE
# 4          premium 2011-02-16 16:00:00         2417        11      US
#
#   currency  delivery_method  \
# 0      USD              0.0
# 1      USD              1.0
# 2      USD              1.0
# 3      EUR              1.0
# 4      USD              0.0
#
#                                          description  \
# 0  <p><a href="http://s432.photobucket.com/albums...
# 1  <p>Join us for a quick, one-night, community-b...
# 2  <h3><span class="subcategory"><strong>Teacher ...
# 3  <p style="margin-bottom: 1.3em; padding-bottom...
# 4  <p>Writers and filmmakers need to understand t...
#
# ...

# %%
'''Gut feel
- fraud events are likely to have more missing data, missing logos, shorter descriptions 
['gts', 'listed', 'payout_type', 'user_type', 'delivery_method', 
'org_facebook', 'org_twitter', 'has_analytics', 'venue_address', 'venue_latitude', 
'venue_country', 'venue_longitude']

All possible fields: 
acct_type             14337 non-null object
approx_payout_date    14337 non-null datetime64[ns]
body_length           14337 non-null int64
channels              14337 non-null int64
country               14256 non-null object
currency              14337 non-null object
delivery_method       14321 non-null float64
description           14337 non-null object
email_domain          14337 non-null object
event_created         14337 non-null int64
event_end             14337 non-null int64
event_published       14238 non-null float64
event_start           14337 non-null int64
fb_published          14337 non-null int64
gts                   14337 non-null float64
has_analytics         14337 non-null int64
has_header            8928 non-null float64
has_logo              14337 non-null int64
listed                14337 non-null object
name                  14337 non-null object
name_length           14337 non-null int64
num_order             14337 non-null int64
num_payouts           14337 non-null int64
object_id             14337 non-null int64
org_desc              14337 non-null object
org_facebook          14278 non-null float64
org_name              14337 non-null object
org_twitter           14278 non-null float64
payee_name            14337 non-null object
payout_type           14337 non-null object
previous_payouts      14337 non-null object
sale_duration         14182 non-null float64
sale_duration2        14337 non-null int64
show_map              14337 non-null int64
ticket_types          14337 non-null object
user_age              14337 non-null int64
user_created          14337 non-null int64
user_type             14337 non-null int64
venue_address         14337 non-null object
venue_country         13261 non-null object
venue_latitude        13261 non-null float64
venue_longitude       13261 non-null float64
venue_name            13261 non-null object
venue_state           13261 non-null object
'''
col = 'has_analytics'
print df.groupby(col).mean()['fraud']
print df.groupby(col).count()['fraud']
# Out:
# has_analytics
# 0    0.063807
# 1    0.002865
# Name: fraud, dtype: float64
# has_analytics
# 0    13290
# 1     1047
# Name: fraud, dtype: int64

# %%
col = 'listed'
print df.groupby(col).mean()['fraud']
print df.groupby(col).count()['fraud']
# Out:
# listed
# n    0.072825
# y    0.057115
# Name: fraud, dtype: float64
# listed
# n     2046
# y    12291
# Name: fraud, dtype: int64

# %%
col = 'payout_type'
print df.groupby(col).mean()['fraud']
print df.groupby(col).count()['fraud']
# Out:
# payout_type
#          0.787018
# ACH      0.041534
# CHECK    0.006293
# Name: fraud, dtype: float64
# payout_type
#            493
# ACH      10666
# CHECK     3178
# Name: fraud, dtype: int64

# %%
col = 'user_type'
print df.groupby(col).mean()['fraud']
print df.groupby(col).count()['fraud']
# Out:
# user_type
# 1      0.174692
# 2      1.000000
# 3      0.018484
# 4      0.019224
# 5      0.000000
# 103    0.000000
# Name: fraud, dtype: float64
# user_type
# 1      3738
# 2         1
# 3      7520
# 4      3017
# 5        59
# 103       2
# Name: fraud, dtype: int64

# %%
col = 'delivery_method'
print df.groupby(col).mean()['fraud']
print df.groupby(col).count()['fraud']
# Out:
# delivery_method
# 0.0    0.094014
# 1.0    0.008462
# 3.0    0.012146
# Name: fraud, dtype: float64
# delivery_method
# 0.0    8520
# 1.0    5554
# 3.0     247
# Name: fraud, dtype: int64

# %%
# some columns contain list, exclude them to prep data for summary
del df['ticket_types']
del df['previous_payouts']

# %%
df.columns
# Out:
# Index([         u'acct_type', u'approx_payout_date',        u'body_length',
#                  u'channels',            u'country',           u'currency',
#           u'delivery_method',        u'description',       u'email_domain',
#             u'event_created',          u'event_end',    u'event_published',
#               u'event_start',       u'fb_published',                u'gts',
#             u'has_analytics',         u'has_header',           u'has_logo',
#                    u'listed',               u'name',        u'name_length',
#                 u'num_order',        u'num_payouts',          u'object_id',
#                  u'org_desc',       u'org_facebook',           u'org_name',
#               u'org_twitter',         u'payee_name',        u'payout_type',
#             u'sale_duration',     u'sale_duration2',           u'show_map',
#                  u'user_age',       u'user_created',          u'user_type',
# ...

# %%
# then split fraud / non_fraud
df_fraud = df[df.fraud==1]
df_non_fraud = df[df.fraud==0]

# %%
# Check how many fraud vs not fraud events
df_fraud.shape
# 851/14337 or ~6% fraud
# Out:
# (851, 43)

# %%
df_non_fraud.shape
# 13486/14337 not fraud
# Out:
# (13486, 43)
